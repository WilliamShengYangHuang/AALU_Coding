# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamShengYangHuang/AALU_Coding/blob/main/Matrix_of_Sorted_Scatter_Points.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import matplotlib.pyplot as plt
import csv

# %%
# Generate a list of 100 random coordinates
coordinates = [(random.uniform(1, 100), random.uniform(1, 100)) for _ in range(100)]

# Sort the coordinates based on the values of x and y
# If two coordinates have the same x value, they are sorted based on their y value.
sorted_coordinates = sorted(coordinates, key=lambda coord: (coord[0], coord[1]))

# Arrange the sorted coordinates into a 10x10 matrix
# This is achieved by slicing the sorted list every 10 elements to create rows for the matrix.
matrix = [sorted_coordinates[i:i + 10] for i in range(0, 100, 10)]

matrix # Display the matrix result
# Out:
# [[(1.1050626002169046, 3.3331896923391167),
#   (1.6820516073438279, 14.05003069813554),
#   (2.278942334321876, 25.56802114574257),
#   (2.8357713543701912, 61.970310940715216),
#   (2.929795063951351, 81.67312432543285),
#   (3.9265341545781043, 76.65766088854579),
#   (5.962583681465068, 51.0412580002449),
#   (7.165690667078223, 86.31282058347924),
#   (7.966668715959477, 33.879532233998795),
#   (8.238842743237424, 5.49139453796037)],
#  [(8.57705605855192, 79.506795546516),
#   (9.203675844105344, 44.2389151474897),
#   (10.111283017824935, 27.07874753027423),
#   (11.858188173788808, 94.68652217737475),
#   (15.907265894732642, 76.1110742306599),
#   (15.94104310133899, 47.26894580168236),
#   (16.58784100142198, 37.05687918527986),
#   (17.942863902822598, 97.1969359506655),
#   (19.168696811720984, 67.04513547811621),
#   (19.783701716911438, 33.71157795432544)],
#  [(20.695729406273927, 84.37321592909807),
#   (20.87077979659045, 50.591631292514236),
#   (24.041732253378445, 38.37727833621045),
#   (24.114831494733316, 9.99330738141402),
#   (25.171537716186478, 19.828598046679225),
#   (26.015954379840963, 19.35226839148611),
#   (27.88107516144199, 74.15950966966808),
#   (28.00608530023072, 62.79311888327181),
#   (28.618028459233262, 79.76347046789235),
#   (28.75865903907811, 42.22261290928844)],
#  [(28.77607370353166, 54.67506937531899),
#   (28.882813122912896, 41.364398409938154),
#   (29.727952482328515, 31.550417121152588),
#   (30.364167121782764, 42.09026941534975),
#   (30.60544317182573, 66.97594784291934),
#   (31.698608592039044, 29.578834851381224),
#   (32.06009813868155, 91.62692511663708),
#   (32.74723903825091, 47.71464590088164),
#   (33.16088884934572, 47.55228074787797),
#   (33.40701469623796, 39.36735856548348)],
#  [(37.593296751030365, 62.24467625168554),
#   (37.710531277116246, 29.047782712421153),
#   (37.89245082009944, 30.75839889142085),
#   (40.86844617294074, 80.54192136968514),
#   (41.28460019346586, 2.3873411661730413),
#   (45.90632242109373, 47.06177490113105),
#   (45.93621024529717, 4.381398922188921),
#   (49.60291375187507, 85.52723159190579),
#   (49.968198990696294, 58.96588896243329),
#   (50.118879350999364, 29.10650190983829)],
#  [(51.05588803901886, 60.36829056373949),
#   (51.48809517714946, 11.684591670600733),
#   (52.10114780656571, 64.51776353664991),
#   (54.41742967840491, 61.998195205211594),
#   (56.06560412731368, 33.719379457017716),
#   (56.24927022673069, 52.37928474358835),
#   (56.36617239246803, 43.40477900269674),
#   (57.776890874466915, 80.61497764413716),
#   (58.62059337050921, 71.41334564702817),
#   (60.956215254238515, 80.61476560150001)],
#  [(62.52186124425571, 91.15319033083507),
#   (62.96332313018717, 86.3619729191649),
#   (63.092066644713654, 86.82672832497065),
#   (63.24195160786043, 96.64625256534892),
#   (63.27367767105439, 64.39358423548818),
#   (64.46077788991838, 81.26124014234473),
#   (65.19850901189227, 76.58007691474498),
#   (65.58389094522009, 32.15215138618831),
#   (66.06856568888833, 37.79540339173486),
#   (66.31472852079033, 42.54901131963259)],
#  [(67.23655406445887, 73.94972126320098),
#   (69.8992663706981, 22.574887218120317),
#   (70.27269125821033, 19.6080485822546),
#   (70.45814725398635, 63.408749394083586),
#   (73.08402665568481, 44.815627626563746),
#   (73.26288974355296, 93.64719412120033),
#   (73.89176755457814, 52.167559149145106),
#   (77.2005109199881, 5.956077647990295),
#   (79.2469516888264, 37.22271962835899),
#   (79.30298986235515, 41.393425633342545)],
#  [(80.51453633442937, 81.5576994255257),
#   (81.276937851763, 74.62179128492699),
#   (81.70051830904848, 89.56169010039824),
#   (82.26148922166183, 11.65283555736546),
#   (82.45800075286422, 97.55093008244695),
#   (85.11623904305384, 15.747966986574719),
#   (86.61048122599453, 41.43142151895083),
#   (89.22430643386421, 12.936475126707395),
#   (90.10615231221607, 35.514566901243086),
#   (91.13409399028367, 53.43834712574656)],
#  [(92.49966386487439, 17.606556797386137),
#   (93.00154033582862, 31.62451107308926),
#   (94.38575106992549, 15.9322680154756),
#   (95.02864484059894, 22.382260670401063),
#   (95.06772875519424, 35.7314054980417),
#   (95.14851529423086, 20.13651432169043),
#   (95.17997658238849, 74.59813564722478),
#   (96.49536966772992, 99.60917096614104),
#   (97.58544668291336, 91.1661580980062),
#   (98.89837356833443, 40.72031208081383)]]

# %%
# Save the matrix to a CSV file
with open('coordinates_matrix.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    for row in matrix:
        writer.writerow(row)

# %%
# Create a scatter plot
x_values = [coord[0] for coord in coordinates]  # Extract x-values
y_values = [coord[1] for coord in coordinates]  # Extract y-values

plt.scatter(x_values, y_values)  # Plot x and y values
plt.title('Scatter Plot of Random Coordinates')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.show()  # Display the plot
